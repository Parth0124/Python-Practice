# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
### series from list

import pandas as pd

data=[1,2,3,4,5]
series = pd.Series(data)

print("Series \n", series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
### series from dictionary

data={'a':1, 'b':2, 'c':3, 'd':4}
series_dictionary = pd.Series(data)

print(series_dictionary)

### keys are considered as index while the values are considered as the series values.
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
### series with index as the keys we want to give.

data=[10,20,30,40]
index=['a', 'b','c', 'd']

pd.Series(data, index=index)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
### Dataframes
### creating a dataframe from a dictionary of list

data={
    'Name':['Parth', 'John', 'Jack'],
    'Age':[25,30,45],
    'City':['Pune','Delhi','Banglore']
}

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      City
# 0  Parth   25      Pune
# 1   John   30     Delhi
# 2   Jack   45  Banglore
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np

np.array(df)
# Out:
# array([['Parth', 25, 'Pune'],
#        ['John', 30, 'Delhi'],
#        ['Jack', 45, 'Banglore']], dtype=object)

# %%
## create a dataframe from a list of dictionaries.

data=[
    {'Name':"Parth", 'Age':25, 'City':"Pune"},
    {'Name':"John", 'Age':35, 'City':"Delhi"},
    {'Name':"Jack", 'Age':45, 'City':"Banglore"},
    {'Name':"Jacob", 'Age':55, 'City':"Hyderabad"}
]

df_dictionary = pd.DataFrame(data)
print(df_dictionary)
print(type(df_dictionary))
# Out:
#     Name  Age       City
# 0  Parth   25       Pune
# 1   John   35      Delhi
# 2   Jack   45   Banglore
# 3  Jacob   55  Hyderabad
# <class 'pandas.core.frame.DataFrame'>

# %%
### read a csv file

df=pd.read_csv('sales_data.csv')
(df.head(20))  ### to get the initial n entries.
# Out:
#     Transaction ID        Date Product Category  \
# 0            10001  2024-01-01      Electronics
# 1            10002  2024-01-02  Home Appliances
# 2            10003  2024-01-03         Clothing
# 3            10004  2024-01-04            Books
# 4            10005  2024-01-05  Beauty Products
# 5            10006  2024-01-06           Sports
# 6            10007  2024-01-07      Electronics
# 7            10008  2024-01-08  Home Appliances
# 8            10009  2024-01-09         Clothing
# 9            10010  2024-01-10            Books
# 10           10011  2024-01-11  Beauty Products
# 11           10012  2024-01-12           Sports
# 12           10013  2024-01-13      Electronics
# 13           10014  2024-01-14  Home Appliances
# 14           10015  2024-01-15         Clothing
# 15           10016  2024-01-16            Books
# 16           10017  2024-01-17  Beauty Products
# 17           10018  2024-01-18           Sports
# ...

# %%
(df.tail(20))  ### to get the final n entries.
# Out:
#      Transaction ID        Date Product Category  \
# 220           10221  2024-08-08  Beauty Products
# 221           10222  2024-08-09           Sports
# 222           10223  2024-08-10      Electronics
# 223           10224  2024-08-11  Home Appliances
# 224           10225  2024-08-12         Clothing
# 225           10226  2024-08-13            Books
# 226           10227  2024-08-14  Beauty Products
# 227           10228  2024-08-15           Sports
# 228           10229  2024-08-16      Electronics
# 229           10230  2024-08-17  Home Appliances
# 230           10231  2024-08-18         Clothing
# 231           10232  2024-08-19            Books
# 232           10233  2024-08-20  Beauty Products
# 233           10234  2024-08-21           Sports
# 234           10235  2024-08-22      Electronics
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# ...

# %%
data
# Out:
# {'Name': ['Parth', 'John', 'Jack'],
#  'Age': [25, 30, 45],
#  'City': ['Pune', 'Delhi', 'Banglore']}

# %%
df
# Out:
#     Name  Age      City
# 0  Parth   25      Pune
# 1   John   30     Delhi
# 2   Jack   45  Banglore

# %%
df['Name']  ### this is case sensitive. name will not work. need to use Name only.
# Out:
# 0    Parth
# 1     John
# 2     Jack
# Name: Name, dtype: object

# %%
df.loc[0]  ### row index.
# Out:
# Name    Parth
# Age        25
# City     Pune
# Name: 0, dtype: object

# %%
df.loc[0][1]
# Out:
# /var/folders/pp/hr12q0qj4x9450xlpzvw9l_m0000gn/T/ipykernel_5861/395987507.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][1]
# 25

# %%
df.iloc[0]   ###column index
# Out:
# Name    Parth
# Age        25
# City     Pune
# Name: 0, dtype: object

# %%
df.iloc[1][0]
# Out:
# /var/folders/pp/hr12q0qj4x9450xlpzvw9l_m0000gn/T/ipykernel_5861/1019881219.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][0]
# 'John'
